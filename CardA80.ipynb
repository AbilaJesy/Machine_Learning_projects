# %% [markdown]
# # READ MY FILE

# %%
import pandas as pd #data manipulation
df=pd.read_csv("cardA80.csv") #read file
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
##information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182274 entries, 0 to 182273
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    182274 non-null  float64
#  1   V1      182274 non-null  float64
#  2   V2      182274 non-null  float64
#  3   V3      182274 non-null  float64
#  4   V4      182274 non-null  float64
#  5   V5      182274 non-null  float64
#  6   V6      182274 non-null  float64
#  7   V7      182274 non-null  float64
#  8   V8      182274 non-null  float64
#  9   V9      182274 non-null  float64
#  10  V10     182274 non-null  float64
#  11  V11     182274 non-null  float64
#  12  V12     182274 non-null  float64
#  13  V13     182274 non-null  float64
#  14  V14     182274 non-null  float64
#  15  V15     182274 non-null  float64
#  16  V16     182274 non-null  float64
#  17  V17     182274 non-null  float64
#  18  V18     182274 non-null  float64
#  19  V19     182274 non-null  float64
#  20  V20     182274 non-null  float64
#  21  V21     182274 non-null  float64
#  22  V22     182274 non-null  float64
#  23  V23     182274 non-null  float64
#  24  V24     182274 non-null  float64
#  25  V25     182274 non-null  float64
#  26  V26     182274 non-null  float64
#  27  V27     182274 non-null  float64
#  28  V28     182274 non-null  float64
#  29  Amount  182274 non-null  float64
#  30  Class   182274 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 43.1 MB

# %%
#shape of row and cloumns
df.shape
# Out:
# (182274, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
#describe of dataset
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  182274.000000  182274.000000  182274.000000  182274.000000
# mean    64950.978137      -0.140701       0.022355       0.417827
# std     30815.326964       1.874027       1.614651       1.416786
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     42405.250000      -0.975746      -0.560169      -0.171580
# 50%     63328.000000      -0.139584       0.094440       0.570861
# 75%     81828.750000       1.196321       0.792099       1.268000
# max    125328.000000       2.439207      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  182274.000000  182274.000000  182274.000000  182274.000000
# mean        0.096571      -0.150216       0.053541      -0.068758
# std         1.384198       1.355220       1.303931       1.212986
# min        -5.683171     -42.147898     -26.160506     -43.557242
# 25%        -0.768879      -0.809988      -0.699651      -0.582851
# 50%         0.099924      -0.203421      -0.209268      -0.023582
# 75%         0.915175       0.412599       0.447020       0.477670
# max        16.875344      34.801666      22.529298      36.677268
#
#                   V8             V9  ...            V21            V22  \
# count  182274.000000  182274.000000  ...  182274.000000  182274.000000
# mean        0.025969       0.014670  ...      -0.021500      -0.067918
# std         1.223872       1.144723  ...       0.742328       0.678178
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.170608      -0.661078  ...      -0.228925      -0.542959
# 50%         0.050410      -0.076819  ...      -0.049475      -0.053427
# 75%         0.344894       0.634279  ...       0.138229       0.389329
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  182274.000000  182274.000000  182274.000000  182274.000000
# mean       -0.019723       0.007219       0.078660       0.010206
# std         0.594928       0.600835       0.476193       0.489617
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.169356      -0.335930      -0.216326      -0.330645
# 50%        -0.032866       0.056790       0.122366      -0.059163
# 75%         0.105952       0.418470       0.393032       0.268708
# max        19.002942       4.022866       7.519589       3.517346
#
#                  V27            V28         Amount          Class
# count  182274.000000  182274.000000  182274.000000  182274.000000
# mean        0.002026       0.002194      88.510460       0.002002
# std         0.392380       0.307282     247.557098       0.044704
# min       -22.565679     -11.710896       0.000000       0.000000
# 25%        -0.066014      -0.034958       5.750000       0.000000
# 50%         0.007463       0.020022      22.400000       0.000000
# 75%         0.089498       0.078217      78.070000       0.000000
# max        12.152401      33.847808   19656.530000       1.000000
#
# [8 rows x 31 columns]

# %%
#Unique target values
df["Class"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Class'].values
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Handling missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # EDA PLOTS

# %%
#check the target value in counter plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Class",data=df)
plt.ylim(0,1000)
plt.show()

#take awey --> in this dataset is imbalance

# %%
sns.distplot(df['Amount'])
plt.xlim(-100,1000)

plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel
# V8      0.008084  0.017298  0.013376  0.025455  0.014275 -0.089376  0.026362
# V9      0.003423  0.042944  0.040327  0.000733 -0.026922 -0.030980 -0.111911
# V10     0.003936  0.017391 -0.000611 -0.014734 -0.027673 -0.111819 -0.268110
# V11     0.018614 -0.066271 -0.007830  0.000589 -0.007193 -0.009072  0.177521
# V12     0.012747  0.056808  0.028772  0.007921  0.000214  0.014142 -0.283717
# V13    -0.019163 -0.007073 -0.003558 -0.002026 -0.004244 -0.005819 -0.002517
# V14     0.012208 -0.055670 -0.000980 -0.003093  0.015549  0.016598 -0.335861
# V15     0.004982 -0.020323 -0.015949  0.003262 -0.008635 -0.023724 -0.008982
# V16    -0.006641  0.052164  0.023111  0.005004 -0.006097 -0.017153 -0.248815
# V17    -0.008680 -0.045659 -0.042120  0.013734 -0.000649  0.017104 -0.405095
# V18    -0.010163  0.006653 -0.001245  0.000020  0.007525  0.041325 -0.151771
# V19    -0.008724 -0.003840 -0.004106 -0.006362 -0.005160 -0.059741  0.046898
# V20    -0.003514 -0.015855  0.005809 -0.017090  0.071924  0.414688  0.023378
# V21     0.005416 -0.006832 -0.016716  0.012160  0.038230  0.127085  0.049229
# V22     0.003886 -0.021832 -0.062305 -0.013591 -0.022410 -0.078558  0.003092
# V23     0.008979  0.036634  0.024039 -0.007055  0.032363 -0.137496 -0.001688
# V24     1.000000 -0.016065 -0.006619 -0.009214  0.001142  0.008777 -0.005880
# V25    -0.016065  1.000000 -0.069217  0.035862  0.036200 -0.061321 -0.000163
# V26    -0.006619 -0.069217  1.000000  0.004184  0.007653  0.007138  0.002506
# V27    -0.009214  0.035862  0.004184  1.000000  0.083644 -0.002866  0.020131
# V28     0.001142  0.036200  0.007653  0.083644  1.000000  0.027640  0.006900
# Amount  0.008777 -0.061321  0.007138 -0.002866  0.027640  1.000000  0.005071
# Class  -0.005880 -0.000163  0.002506  0.020131  0.006900  0.005071  1.000000
#
# [31 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

df['Time']=sc.fit_transform(df['Time'].values.reshape(-1, 1))
df['Amount']=sc.fit_transform(df['Amount'].values.reshape(-1, 1))

# %% [markdown]
# # Splitting X and Y features

# %%
X =df.drop("Class", axis=1)
Y = df["Class"]

# %% [markdown]
# # Dataset is imbalance so using over sampling Preprocessing techniques

# %%
from imblearn.over_sampling import SMOTE
oversampler = SMOTE(random_state=2)
X_new , Y_new = oversampler.fit_resample(X, Y)

# %% [markdown]
# # visuvalizing balanced data

# %%
sns.countplot(x=Y_new)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # splitting dataset train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_new,Y_new,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.transform(x_test)

# %%
import pickle
pickle.dump(sc,open('scaling.pkl','wb'))

# %% [markdown]
# # Algorithm Model_selection

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=20)

# %%
#fit the training dataset
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %% [markdown]
# # Predict the training dataset

# %%
x_train_predict=rf.predict(x_train)

# %% [markdown]
# # Mertrics---> error rate

# %%
from sklearn.metrics import accuracy_score as acc,recall_score as rs,precision_score as ps,f1_score as f1,confusion_matrix as cm,roc_curve,auc

print('Accuracy_score\t:',acc(y_train,x_train_predict))
print('recall_score\t:',rs(y_train,x_train_predict))
print('precision_score\t:',ps(y_train,x_train_predict))
print('f1_score\t:',f1(y_train,x_train_predict))
print('Confusion matrix:\n\n',cm(y_train,x_train_predict))
# Out:
# Accuracy_score	: 0.9999965642114522
# recall_score	: 1.0
# precision_score	: 0.999993130075157
# f1_score	: 0.9999965650257795
# Confusion matrix:
#
#  [[145492      1]
#  [     0 145561]]

# %%
fpr, tpr, thresholds = roc_curve(y_train, x_train_predict)
roc_auc = auc(fpr, tpr)
# Plot the ROC curve
plt.plot(fpr, tpr, lw=1, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], '--', color='gray', lw=1)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Predict the testing dataset

# %%
x_test_predict=rf.predict(x_test)

# %%
print('Accuracy_score\t:',acc(y_test,x_test_predict))
print('recall_score\t:',rs(y_test,x_test_predict))
print('precision_score\t:',ps(y_test,x_test_predict))
print('f1_score\t:',f1(y_test,x_test_predict))
print('Confusion matrix:\n\n',cm(y_test,x_test_predict))
# Out:
# Accuracy_score	: 0.9999175416414711
# recall_score	: 1.0
# precision_score	: 0.9998349562634098
# f1_score	: 0.9999174713212842
# Confusion matrix:
#
#  [[36410     6]
#  [    0 36348]]

# %%
fpr, tpr, thresholds = roc_curve(y_test,x_test_predict)
roc_auc = auc(fpr, tpr)
# Plot the ROC curve
plt.plot(fpr, tpr, lw=1, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], '--', color='gray', lw=1)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # New data

# %%
df.iloc[0]
# Out:
# Time     -2.107755
# V1       -1.359807
# V2       -0.072781
# V3        2.536347
# V4        1.378155
# V5       -0.338321
# V6        0.462388
# V7        0.239599
# V8        0.098698
# V9        0.363787
# V10       0.090794
# V11      -0.551600
# V12      -0.617801
# V13      -0.991390
# V14      -0.311169
# V15       1.468177
# V16      -0.470401
# V17       0.207971
# V18       0.025791
# V19       0.403993
# V20       0.251412
# V21      -0.018307
# V22       0.277838
# V23      -0.110474
# V24       0.066928
# V25       0.128539
# V26      -0.189115
# V27       0.133558
# V28      -0.021053
# Amount    0.246851
# Class     0.000000
# Name: 0, dtype: float64

# %%
sc.transform(df.iloc[0].values.reshape(-1,1))
# Out:
# array([[-0.36605076],
#        [-0.36302944],
#        [-0.35783052],
#        [-0.34729099],
#        [-0.35196948],
#        [-0.35890316],
#        [-0.35566871],
#        [-0.35656866],
#        [-0.35713783],
#        [-0.35606701],
#        [-0.35716976],
#        [-0.3597647 ],
#        [-0.36003212],
#        [-0.36154122],
#        [-0.35879348],
#        [-0.35160584],
#        [-0.35943669],
#        [-0.35669642],
#        [-0.35743234],
#        [-0.3559046 ],
#        [-0.35652094],
#        [-0.35761047],
#        [-0.3564142 ],
#        [-0.35798278],
#        [-0.35726616],
#        [-0.35701729],
#        [-0.35830045],
#        [-0.35699701],
#        [-0.35762156],
#        [-0.35653937],
#        [-0.35753652]])

# %% [markdown]
# # pickle the model

# %%
import pickle
pickle_out = open("Randomforestmodel_cardA80.pkl","wb")
pickle.dump(rf, pickle_out)

# %%
pickle_model=pickle.load(open("Randomforestmodel_cardA80.pkl","rb"))

# %%
pickle_out.close()

print("Model Saved Successfully...")
# Out:
# Model Saved Successfully...
